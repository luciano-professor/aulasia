# %% [markdown]
# # Meu primeiro notebook pyhton

# %% [markdown]
# ## Vamos importar as bibliotecas que usaremos para as Regras de Associação

# %% [markdown]
# ## Primera Forma de Fazer (sem ler arquivo externo)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# **Criar a variável com os dados**

# %%
dados = [
    ['leite', 'cerveja', 'pao', 'manteiga'],
    ['cafe', 'pao', 'manteiga'],
    ['cafe', 'pao', 'manteiga'],
    ['leite', 'cafe', 'pao', 'manteiga'],
    ['cerveja'],
    ['manteiga'],
    ['pao'],
    ['feijao'],
    ['arroz', 'feijao'],
    ['arroz']
]

# %% [markdown]
# **Transformar os dado de forma que o algoritmo apriori consiga trabalhar**

# %%
te = TransactionEncoder() #quando usa os dados na forma acima te que fazer isso
arr = te.fit(dados).transform(dados) #transformando os dados
df = pd.DataFrame(arr, columns=te.columns_) #jogando os dados num DataFrame
df #imprimindo o dataframe
# Out:
#    arroz   cafe  cerveja  feijao  leite  manteiga    pao
# 0  False  False     True   False   True      True   True
# 1  False   True    False   False  False      True   True
# 2  False   True    False   False  False      True   True
# 3  False   True    False   False   True      True   True
# 4  False  False     True   False  False     False  False
# 5  False  False    False   False  False      True  False
# 6  False  False    False   False  False     False   True
# 7  False  False    False    True  False     False  False
# 8   True  False    False    True  False     False  False
# 9   True  False    False   False  False     False  False

# %%
#calculando o suporte
suportes = apriori(df, min_support=0.3, use_colnames=True)
suportes #imprime os suportes
# Out:
#    support               itemsets
# 0      0.3                 (cafe)
# 1      0.5             (manteiga)
# 2      0.5                  (pao)
# 3      0.3       (cafe, manteiga)
# 4      0.3            (cafe, pao)
# 5      0.4        (manteiga, pao)
# 6      0.3  (cafe, pao, manteiga)

# %% [markdown]
# **Gerando Regras de Associacao**

# %%
from mlxtend.frequent_patterns import association_rules
#mandando calcular as regras com confianca minima 0.8
regras = association_rules(suportes, metric="confidence", min_threshold=0.8)
regras
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0            (cafe)       (manteiga)                 0.3                 0.5
# 1            (cafe)            (pao)                 0.3                 0.5
# 2        (manteiga)            (pao)                 0.5                 0.5
# 3             (pao)       (manteiga)                 0.5                 0.5
# 4       (cafe, pao)       (manteiga)                 0.3                 0.5
# 5  (cafe, manteiga)            (pao)                 0.3                 0.5
# 6            (cafe)  (pao, manteiga)                 0.3                 0.4
#
#    support  confidence  lift  leverage  conviction
# 0      0.3         1.0   2.0      0.15         inf
# 1      0.3         1.0   2.0      0.15         inf
# 2      0.4         0.8   1.6      0.15    2.500000
# 3      0.4         0.8   1.6      0.15    2.500000
# 4      0.3         1.0   2.0      0.15         inf
# 5      0.3         1.0   2.0      0.15         inf
# 6      0.3         1.0   2.5      0.18         inf

# %% [markdown]
# # Lendo os dados de um arquivo CSV

# %%
dados2 = pd.read_csv('mercado2ml.csv') #lendo o csv
#calculando o suporte
suportes2 = apriori(dados2, min_support=0.3, use_colnames=True)
suportes2 #imprime os suportes
# Out:
#    support               itemsets
# 0      0.3                 (cafe)
# 1      0.5             (manteiga)
# 2      0.5                  (pao)
# 3      0.3       (cafe, manteiga)
# 4      0.3            (cafe, pao)
# 5      0.4        (manteiga, pao)
# 6      0.3  (cafe, pao, manteiga)

# %%
#mandando calcular as regras com confianca minima 0.8
regras2 = association_rules(suportes2, metric="confidence", min_threshold=0.8)
regras2
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0            (cafe)            (pao)                 0.3                 0.5
# 1            (cafe)       (manteiga)                 0.3                 0.5
# 2             (pao)       (manteiga)                 0.5                 0.5
# 3        (manteiga)            (pao)                 0.5                 0.5
# 4       (cafe, pao)       (manteiga)                 0.3                 0.5
# 5  (cafe, manteiga)            (pao)                 0.3                 0.5
# 6            (cafe)  (pao, manteiga)                 0.3                 0.4
#
#    support  confidence  lift  leverage  conviction
# 0      0.3         1.0   2.0      0.15         inf
# 1      0.3         1.0   2.0      0.15         inf
# 2      0.4         0.8   1.6      0.15    2.500000
# 3      0.4         0.8   1.6      0.15    2.500000
# 4      0.3         1.0   2.0      0.15         inf
# 5      0.3         1.0   2.0      0.15         inf
# 6      0.3         1.0   2.5      0.18         inf
